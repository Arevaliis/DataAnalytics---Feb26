# %% [markdown]
# ### Filtrado de Datos:

# %% [markdown]
# ---
# ### Uso de .loc[ ] y .iloc[ ]
# ---
# En Pandas, el filtrado o selección de datos es esencial para explorar y manipular DataFrames.
#
# Los métodos principales para seleccionar datos concretos de un DataFrame y poder manipularlos son loc e iloc .
#
# .loc[ ] y .iloc[ ]
# Ambos métodos se usan para acceder a subconjuntos de datos, pero con diferentes lógicas:
#
# ### <span style="color:darksalmon;">.loc[ ]: Selección basada en etiquetas (nombres) de filas y columnas.</span>
#
# ```python
# #Sintaxis general
# df.loc[etiqueta_filas,etiqueta_columnas]
#
# Uso típico de .loc[]:
#
# df.loc[fila, columna]
# ```
# Si no se especifica columna, se seleccionan todas.
#
# Permite condiciones booleanas para filtrar filas.

# %% [markdown]
# ### <span style="color:darksalmon;">.iloc[ ]: Selección basada en índices numéricos (enteros) de filas y columnas.</span>
#
# ```python
# #Sintaxis general
# df.iloc[índice_filas,índice_columnas]
#
# Uso típico de .iloc[]:
#
# df.iloc[fila, columna]
# ```
# Funciona por posición: el índice 0 es la primera fila/columna.
#
# No admite etiquetas o condiciones lógicas directamente.

# %% [markdown]
# ### Cuadro explicativo
#
# | Método    | Basado en       | Sintaxis             | Permite condiciones | Ejemplo                   |
# | --------- | --------------- | -------------------- | ------------------- | ------------------------- |
# | `.loc[]`  | Etiquetas       | `df.loc["a", "col"]` | ✅ Sí                | `df.loc[df["edad"] > 30]` |
# | `.iloc[]` | Índices enteros | `df.iloc[0, 1]`      | ❌ No                | `df.iloc[0:3, :]`         |

# %% [markdown]
# ### <span style="color:darksalmon;"> Veamos un ejemplo con un  DataFrame:</span>

# %%
import pandas as pd
# Cargar archivo CSV en un DataFrame
df = pd.read_csv('Online Sales Data.csv')
df.sample(5)
# Out:
#      Transaction ID        Date Product Category  \
# 209           10210  2024-07-28           Sports
# 3             10004  2024-01-04            Books
# 90            10091  2024-03-31      Electronics
# 23            10024  2024-01-24           Sports
# 48            10049  2024-02-18      Electronics
#
#                                   Product Name  Units Sold  Unit Price  \
# 209  Bose SoundLink Color Bluetooth Speaker II           1      129.00
# 3                            The Da Vinci Code           4       15.99
# 90                  Logitech MX Master 3 Mouse           2       99.99
# 23              Adidas FIFA World Cup Football           3       29.99
# 48                           Kindle Paperwhite           2      129.99
#
#      Total Revenue         Region Payment Method
# 209         129.00           Asia    Credit Card
# 3            63.96  North America    Credit Card
# 90          199.98  North America    Credit Card
# 23           89.97           Asia    Credit Card
# 48          259.98  North America    Credit Card

# %% [markdown]
# - Selecciona todas las ventas y muestra las columnas `Date`, `Product Category` y `Unit Price` usando `loc[ ]`

# %%
df.loc[:,['Date', 'Product Category', 'Units Sold']]
# Out:
#            Date Product Category  Units Sold
# 0    2024-01-01      Electronics           2
# 1    2024-01-02  Home Appliances           1
# 2    2024-01-03         Clothing           3
# 3    2024-01-04            Books           4
# 4    2024-01-05  Beauty Products           1
# ..          ...              ...         ...
# 235  2024-08-23  Home Appliances           1
# 236  2024-08-24         Clothing           3
# 237  2024-08-25            Books           3
# 238  2024-08-26  Beauty Products           1
# 239  2024-08-27           Sports           2
#
# [240 rows x 3 columns]

# %% [markdown]
# - Utiliza `iloc [ ]` para seleccionar las primeras 10 filas del DataFrame y muestra las columnas `Product Category` , `Product Name` y `Unit Price`

# %%
df.iloc[:10,[2,3,5]]
# Out:
#   Product Category                 Product Name  Unit Price
# 0      Electronics                iPhone 14 Pro      999.99
# 1  Home Appliances             Dyson V11 Vacuum      499.99
# 2         Clothing             Levi's 501 Jeans       69.99
# 3            Books            The Da Vinci Code       15.99
# 4  Beauty Products      Neutrogena Skincare Set       89.99
# 5           Sports  Wilson Evolution Basketball       29.99
# 6      Electronics          MacBook Pro 16-inch     2499.99
# 7  Home Appliances         Blueair Classic 480i      599.99
# 8         Clothing             Nike Air Force 1       89.99
# 9            Books        Dune by Frank Herbert       25.99

# %% [markdown]
# ### En Pandas existen varios métodos para poder filtrar los datos de un DataFrame. Los más comunes son:
#
# - **Operadores de comparación**: Son básicamente los mismos que vimos en el módulo de Python. Es una forma de filtrado muy útil para seleccionar filas basadas en condiciones. Los pasos a seguir serían:
#
#     - **Creamos la condición:** Para ello usaremos los operadores de comparación de Python (>, <, >=, <=, ==, !=)
#
#     - **Aplicar la condición de filtrado:** Una vez creada la condición es momento de aplicarla con [ ] al DataFrame. Esto nos devolverá las filas que cumplen la condición.
#
#     - **Combinar condiciones:** Es posible combinar varias condiciones utilizando los operadores **&** (*and*) y **|** (*or*).
#
#     ```python
#     unit_price = df['Unit Price'] > 1000
#     unit_sold = df['Units Sold'] > 5
#
#     df[unit_price & unit_sold].loc[:,['Product Name', 'Product Category', 'Unit Price', 'Units Sold']]
#     ```
#
# ### Veámoslo con un ejemplo:

# %%
unit_price = df['Unit Price'] > 100
unit_sold = df['Units Sold'] > 1
Total_Revenue= df['Total Revenue'] > 200

df_filtrado=df[unit_price & unit_sold & Total_Revenue].loc[:,['Product Name', 'Product Category', 'Unit Price', 'Units Sold','Total Revenue']]

# %%
df_filtrado
# Out:
#                                  Product Name Product Category  Unit Price  \
# 0                               iPhone 14 Pro      Electronics      999.99
# 7                        Blueair Classic 480i  Home Appliances      599.99
# 11           Babolat Pure Drive Tennis Racket           Sports      199.99
# 12                      Samsung Galaxy Tab S8      Electronics      749.99
# 14                     North Face Down Jacket         Clothing      249.99
# 17                       Manduka PRO Yoga Mat           Sports      119.99
# 18                      Garmin Forerunner 945      Electronics      499.99
# 26                    Adidas Ultraboost Shoes         Clothing      179.99
# 29                   Nike Air Zoom Pegasus 37           Sports      129.99
# 30                 Sony WH-1000XM4 Headphones      Electronics      349.99
# 36                       Apple Watch Series 8      Electronics      399.99
# 37                                 Roomba i7+  Home Appliances      799.99
# 41                            Fitbit Charge 5           Sports      129.99
# 42                         GoPro HERO10 Black      Electronics      399.99
# 44                   Patagonia Better Sweater         Clothing      139.99
# 48                          Kindle Paperwhite      Electronics      129.99
# 50                 Ray-Ban Aviator Sunglasses         Clothing      154.99
# 60                            Nintendo Switch      Electronics      299.99
# 61                       Philips Airfryer XXL  Home Appliances      199.99
# 65                            Garmin Edge 530           Sports      299.99
# 67                           Eufy RoboVac 11S  Home Appliances      219.99
# 71                              Nike Metcon 6           Sports      129.99
# 78                          Apple AirPods Pro      Electronics      249.99
# 85                                 LG OLED TV  Home Appliances     1299.99
# 89                     On Running Cloud Shoes           Sports      129.99
# 96            Bose SoundLink Revolve+ Speaker      Electronics      299.99
# 101           Under Armour HOVR Sonic 4 Shoes           Sports      109.99
# 103                     Shark IQ Robot Vacuum  Home Appliances      349.99
# 108                       Google Nest Hub Max      Electronics      229.99
# 113                            Fitbit Versa 3           Sports      229.95
# 115                      Breville Smart Grill  Home Appliances      299.95
# 120                            Apple iPad Air      Electronics      599.99
# 127               Dyson Supersonic Hair Dryer  Home Appliances      399.99
# 145                   Cuisinart Coffee Center  Home Appliances      199.95
# 149          Bose SoundSport Wireless Earbuds           Sports      149.99
# 151               Ninja Foodi Pressure Cooker  Home Appliances      199.99
# 169                  Instant Pot Duo Evo Plus  Home Appliances      139.99
# 187                    Anova Precision Cooker  Home Appliances      199.00
# 194           Adidas Ultraboost Running Shoes         Clothing      179.99
# 198                               Apple TV 4K      Electronics      179.00
# 211               Keurig K-Elite Coffee Maker  Home Appliances      169.99
# 223  Philips Sonicare DiamondClean Toothbrush  Home Appliances      229.99
# 227                               Fitbit Luxe           Sports      149.95
#
#      Units Sold  Total Revenue
# 0             2        1999.98
# 7             2        1199.98
# 11            3         599.97
# 12            2        1499.98
# 14            2         499.98
# 17            4         479.96
# 18            2         999.98
# 26            2         359.98
# 29            2         259.98
# 30            2         699.98
# 36            3        1199.97
# 37            2        1599.98
# 41            2         259.98
# 42            3        1199.97
# 44            2         279.98
# 48            2         259.98
# 50            3         464.97
# 60            3         899.97
# 61            2         399.98
# 65            2         599.98
# 67            3         659.97
# 71            3         389.97
# 78            2         499.98
# 85            2        2599.98
# 89            2         259.98
# 96            3         899.97
# 101           2         219.98
# 103           2         699.98
# 108           2         459.98
# 113           3         689.85
# 115           2         599.90
# 120           2        1199.98
# 127           2         799.98
# 145           2         399.90
# 149           2         299.98
# 151           2         399.98
# 169           2         279.98
# 187           2         398.00
# 194           2         359.98
# 198           2         358.00
# 211           2         339.98
# 223           2         459.98
# 227           2         299.90

# %% [markdown]
# ### Veamos algunas otras posibilidades de Filtrado:

# %% [markdown]
# 1. Filtrar todas las transacciones hechas con PayPal:

# %%
df.head(2)
# Out:
#    Transaction ID        Date Product Category      Product Name  Units Sold  \
# 0           10001  2024-01-01      Electronics     iPhone 14 Pro           2
# 1           10002  2024-01-02  Home Appliances  Dyson V11 Vacuum           1
#
#    Unit Price  Total Revenue         Region Payment Method
# 0      999.99        1999.98  North America    Credit Card
# 1      499.99         499.99         Europe         PayPal

# %%
paypal_df = df[df["Payment Method"] == "PayPal"]
paypal_df
# Out:
#      Transaction ID        Date Product Category  \
# 1             10002  2024-01-02  Home Appliances
# 4             10005  2024-01-05  Beauty Products
# 7             10008  2024-01-08  Home Appliances
# 10            10011  2024-01-11  Beauty Products
# 13            10014  2024-01-14  Home Appliances
# ..              ...         ...              ...
# 226           10227  2024-08-14  Beauty Products
# 229           10230  2024-08-17  Home Appliances
# 232           10233  2024-08-20  Beauty Products
# 235           10236  2024-08-23  Home Appliances
# 238           10239  2024-08-26  Beauty Products
#
#                                         Product Name  Units Sold  Unit Price  \
# 1                                   Dyson V11 Vacuum           1      499.99
# 4                            Neutrogena Skincare Set           1       89.99
# 7                               Blueair Classic 480i           2      599.99
# 10                              Chanel No. 5 Perfume           1      129.99
# 13                       Keurig K-Elite Coffee Maker           1      189.99
# ..                                               ...         ...         ...
# 226         The Ordinary Caffeine Solution 5% + EGCG           1        6.70
# 229                             Anova Precision Oven           1      599.00
# 232                        Fresh Sugar Lip Treatment           1       24.00
# 235  Nespresso Vertuo Next Coffee and Espresso Maker           1      159.99
# 238             Sunday Riley Luna Sleeping Night Oil           1       55.00
#
#      Total Revenue  Region Payment Method
# 1           499.99  Europe         PayPal
# 4            89.99  Europe         PayPal
# 7          1199.98  Europe         PayPal
# 10          129.99  Europe         PayPal
# 13          189.99  Europe         PayPal
# ..             ...     ...            ...
# 226           6.70  Europe         PayPal
# 229         599.00  Europe         PayPal
# 232          24.00  Europe         PayPal
# 235         159.99  Europe         PayPal
# 238          55.00  Europe         PayPal
#
# [80 rows x 9 columns]

# %% [markdown]
# 2. Filtrar productos vendidos en la región Asia

# %%
asia_df = df[df["Region"] == "Asia"]
asia_df
# Out:
#      Transaction ID        Date Product Category  \
# 2             10003  2024-01-03         Clothing
# 5             10006  2024-01-06           Sports
# 8             10009  2024-01-09         Clothing
# 11            10012  2024-01-12           Sports
# 14            10015  2024-01-15         Clothing
# ..              ...         ...              ...
# 227           10228  2024-08-15           Sports
# 230           10231  2024-08-18         Clothing
# 233           10234  2024-08-21           Sports
# 236           10237  2024-08-24         Clothing
# 239           10240  2024-08-27           Sports
#
#                                 Product Name  Units Sold  Unit Price  \
# 2                           Levi's 501 Jeans           3       69.99
# 5                Wilson Evolution Basketball           5       29.99
# 8                           Nike Air Force 1           6       89.99
# 11          Babolat Pure Drive Tennis Racket           3      199.99
# 14                    North Face Down Jacket           2      249.99
# ..                                       ...         ...         ...
# 227                              Fitbit Luxe           2      149.95
# 230          Adidas Originals Trefoil Hoodie           4       64.99
# 233  Hydro Flask Standard Mouth Water Bottle           3       32.95
# 236                Nike Air Force 1 Sneakers           3       90.00
# 239               Yeti Rambler 20 oz Tumbler           2       29.99
#
#      Total Revenue Region Payment Method
# 2           209.97   Asia     Debit Card
# 5           149.95   Asia    Credit Card
# 8           539.94   Asia     Debit Card
# 11          599.97   Asia    Credit Card
# 14          499.98   Asia     Debit Card
# ..             ...    ...            ...
# 227         299.90   Asia    Credit Card
# 230         259.96   Asia     Debit Card
# 233          98.85   Asia    Credit Card
# 236         270.00   Asia     Debit Card
# 239          59.98   Asia    Credit Card
#
# [80 rows x 9 columns]

# %% [markdown]
# 3. Filtrar productos vendidos en la región Asia , pero solo mostrar las columnas Product Category y Product Name

# %%
resultado = df.loc[df["Region"] == "Asia", ["Product Category", "Product Name"]]
resultado
# Out:
#     Product Category                             Product Name
# 2           Clothing                         Levi's 501 Jeans
# 5             Sports              Wilson Evolution Basketball
# 8           Clothing                         Nike Air Force 1
# 11            Sports         Babolat Pure Drive Tennis Racket
# 14          Clothing                   North Face Down Jacket
# ..               ...                                      ...
# 227           Sports                              Fitbit Luxe
# 230         Clothing          Adidas Originals Trefoil Hoodie
# 233           Sports  Hydro Flask Standard Mouth Water Bottle
# 236         Clothing                Nike Air Force 1 Sneakers
# 239           Sports               Yeti Rambler 20 oz Tumbler
#
# [80 rows x 2 columns]

# %% [markdown]
# ---
# ###  Filtrado con .isin()
# ---

# %% [markdown]
# El método .isin( ) se utiliza para filtrar filas que contienen uno o varios valores específicos dentro de una columna.
#
# Es muy útil cuando queremos comprobar si un valor pertenece a una lista de opciones.
#
# ### Pasos:
#
# - Crear una lista de valores de interés
#
# - Aplicar .isin(lista) a una columna específica
#
# - Combinar con un filtro booleano y seleccionar columnas si se desea

# %% [markdown]
# Ejemplo 1: Transacciones en la región "Asia" o "Europe"

# %%
regiones = ["Asia", "Europe"]
filtro = df[df["Region"].isin(regiones)]
filtro.sample(5)
# Out:
#      Transaction ID        Date Product Category  \
# 83            10084  2024-03-24           Sports
# 167           10168  2024-06-16           Sports
# 40            10041  2024-02-10  Beauty Products
# 188           10189  2024-07-07         Clothing
# 34            10035  2024-02-04  Beauty Products
#
#                            Product Name  Units Sold  Unit Price  \
# 83       Spalding NBA Street Basketball           6       24.99
# 167                 Yeti Rambler Bottle           3       49.99
# 40   Estee Lauder Advanced Night Repair           1      105.00
# 188        Nike Dri-FIT Training Shorts           4       34.99
# 34             L'Oreal Revitalift Serum           2       39.99
#
#      Total Revenue  Region Payment Method
# 83          149.94    Asia    Credit Card
# 167         149.97    Asia    Credit Card
# 40          105.00  Europe         PayPal
# 188         139.96    Asia     Debit Card
# 34           79.98  Europe         PayPal

# %%
filtro[["Transaction ID", "Region", "Product Name"]]
# Out:
#      Transaction ID  Region                                     Product Name
# 1             10002  Europe                                 Dyson V11 Vacuum
# 2             10003    Asia                                 Levi's 501 Jeans
# 4             10005  Europe                          Neutrogena Skincare Set
# 5             10006    Asia                      Wilson Evolution Basketball
# 7             10008  Europe                             Blueair Classic 480i
# ..              ...     ...                                              ...
# 233           10234    Asia          Hydro Flask Standard Mouth Water Bottle
# 235           10236  Europe  Nespresso Vertuo Next Coffee and Espresso Maker
# 236           10237    Asia                        Nike Air Force 1 Sneakers
# 238           10239  Europe             Sunday Riley Luna Sleeping Night Oil
# 239           10240    Asia                       Yeti Rambler 20 oz Tumbler
#
# [160 rows x 3 columns]

# %% [markdown]
# Ejemplo 2: Productos específicos – "Gap High Rise Skinny Jeans" o "Hanes ComfortSoft T-Shirt"

# %%
productos = ["Gap High Rise Skinny Jeans", "Hanes ComfortSoft T-Shirt"]
filtro = df[df["Product Name"].isin(productos)]
filtro[["Product Name", "Units Sold", "Region"]]
# Out:
#                    Product Name  Units Sold Region
# 62    Hanes ComfortSoft T-Shirt          10   Asia
# 116  Gap High Rise Skinny Jeans           3   Asia

# %% [markdown]
# Ejemplo 3: Productos vendidos en Asia que estén en una lista específica

# %%
df
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# 3                                  The Da Vinci Code           4       15.99
# 4                            Neutrogena Skincare Set           1       89.99
# ..                                               ...         ...         ...
# 235  Nespresso Vertuo Next Coffee and Espresso Maker           1      159.99
# 236                        Nike Air Force 1 Sneakers           3       90.00
# 237           The Handmaid's Tale by Margaret Atwood           3       10.99
# 238             Sunday Riley Luna Sleeping Night Oil           1       55.00
# 239                       Yeti Rambler 20 oz Tumbler           2       29.99
#
#      Total Revenue         Region Payment Method
# 0          1999.98  North America    Credit Card
# 1           499.99         Europe         PayPal
# 2           209.97           Asia     Debit Card
# 3            63.96  North America    Credit Card
# 4            89.99         Europe         PayPal
# ..             ...            ...            ...
# 235         159.99         Europe         PayPal
# 236         270.00           Asia     Debit Card
# 237          32.97  North America    Credit Card
# 238          55.00         Europe         PayPal
# 239          59.98           Asia    Credit Card
#
# [240 rows x 9 columns]

# %%
productos = ["Gap High Rise Skinny Jeans", "Gap 1969 Original Fit Jeans"]
filtro = df[df["Region"].isin(['Asia']) & df["Product Name"].isin(productos)]
filtro[["Product Category", "Product Name", "Units Sold"]]
# Out:
#     Product Category                 Product Name  Units Sold
# 116         Clothing   Gap High Rise Skinny Jeans           3
# 200         Clothing  Gap 1969 Original Fit Jeans           3

# %% [markdown]
# Ejemplo 4: Producto "Gap 1969 Original Fit Jeans" vendido en "Asia"

# %%
producto = ["Gap 1969 Original Fit Jeans"]
region = ["Asia"]

filtro = df[df["Product Name"].isin(producto) & df["Region"].isin(region)]
filtro[["Transaction ID", "Product Name", "Units Sold", "Total Revenue"]]
# Out:
#      Transaction ID                 Product Name  Units Sold  Total Revenue
# 200           10201  Gap 1969 Original Fit Jeans           3         179.97

# %% [markdown]
# ---
# ###  Filtrado con .between( )
# ---

# %% [markdown]
# El método .between() se usa para filtrar filas en un DataFrame que tengan valores dentro de un rango numérico o de fechas.
#
# La estructura general de este método es:
#
# ```python
#
# df[columna].between(inicio, fin, inclusive = both)
#
# '''Donde:
#
# - df: Nombre del DataFrame que vamos a utilizar.
# - columna: Columna específica donde vamos a filtrar.
# - inicio y fin: Indica el intervalo de valores que queremos filtrar.
# - inclusive (opcional): Delimita si los valores del rango están incluidos o no.
#     - left: Incluye sólo el inicio.
#     - right: Incluye sólo el final.
#     - both: Incluye ambos.
#     - neither: No incluye ninguno.'''
# ```

# %% [markdown]
# | Parámetro   | Descripción                                                                             |
# | ----------- | --------------------------------------------------------------------------------------- |
# | `columna`   | Columna sobre la que se aplica el filtro.                                               |
# | `inicio`    | Valor mínimo del rango.                                                                 |
# | `fin`       | Valor máximo del rango.                                                                 |
# | `inclusive` | Define si se incluyen los límites. Valores: `'both'`, `'left'`, `'right'`, `'neither'`. |

# %% [markdown]
# Ejemplo 1: Unit Price entre 10 y 50 (inclusive ambos)

# %%
df[df["Unit Price"].between(10, 50, inclusive="both")][["Transaction ID", "Product Name", "Unit Price", "Units Sold"]]
# Out:
#      Transaction ID                             Product Name  Unit Price  \
# 3             10004                        The Da Vinci Code       15.99
# 5             10006              Wilson Evolution Basketball       29.99
# 9             10010                    Dune by Frank Herbert       25.99
# 15            10016    Salt, Fat, Acid, Heat by Samin Nosrat       35.99
# 21            10022               Gone Girl by Gillian Flynn       22.99
# ..              ...                                      ...         ...
# 225           10226   The Silent Patient by Alex Michaelides       26.99
# 232           10233                Fresh Sugar Lip Treatment       24.00
# 233           10234  Hydro Flask Standard Mouth Water Bottle       32.95
# 237           10238   The Handmaid's Tale by Margaret Atwood       10.99
# 239           10240               Yeti Rambler 20 oz Tumbler       29.99
#
#      Units Sold
# 3             4
# 5             5
# 9             2
# 15            3
# 21            2
# ..          ...
# 225           3
# 232           1
# 233           3
# 237           3
# 239           2
#
# [84 rows x 4 columns]

# %% [markdown]
# Ejemplo 2: Total Revenue entre 100 y 180 (solo extremos)

# %%
df[df["Total Revenue"].between(100, 180, inclusive="both")][["Transaction ID", "Product Name", "Total Revenue"]]
# Out:
#      Transaction ID                                     Product Name  \
# 5             10006                      Wilson Evolution Basketball
# 10            10011                             Chanel No. 5 Perfume
# 15            10016            Salt, Fat, Acid, Heat by Samin Nosrat
# 20            10021                                Zara Summer Dress
# 25            10026                    Panasonic NN-SN966S Microwave
# 32            10033                    Under Armour HeatGear T-Shirt
# 40            10041               Estee Lauder Advanced Night Repair
# 45            10046                       Becoming by Michelle Obama
# 56            10057                        Calvin Klein Boxer Briefs
# 64            10065                         Lancome La Vie Est Belle
# 80            10081                            Levi's Trucker Jacket
# 82            10083                    Charlotte Tilbury Magic Cream
# 83            10084                   Spalding NBA Street Basketball
# 88            10089                          Sunday Riley Good Genes
# 91            10092                            Instant Pot Duo Crisp
# 98            10099                   Gap Essential Crewneck T-Shirt
# 104           10105                               H&M Slim Fit Jeans
# 109           10110                        Cuisinart Griddler Deluxe
# 116           10117                       Gap High Rise Skinny Jeans
# 131           10132              Hydro Flask Wide Mouth Water Bottle
# 133           10134                       Keurig K-Mini Coffee Maker
# 134           10135                          Gap Crewneck Sweatshirt
# 139           10140                                Instant Pot Ultra
# 140           10141                     Adidas Essential Track Pants
# 152           10153               Nike Sportswear Club Fleece Hoodie
# 164           10165                          Adidas 3-Stripes Shorts
# 167           10168                              Yeti Rambler Bottle
# 170           10171                        Nike Tempo Running Shorts
# 174           10175                          Amazon Fire TV Stick 4K
# 179           10180                       Oakley Holbrook Sunglasses
# 182           10183                        Levi's 511 Slim Fit Jeans
# 188           10189                     Nike Dri-FIT Training Shorts
# 191           10192        TRX All-in-One Suspension Training System
# 196           10197                    Tom Ford Black Orchid Perfume
# 200           10201                      Gap 1969 Original Fit Jeans
# 209           10210        Bose SoundLink Color Bluetooth Speaker II
# 218           10219                    Champion Reverse Weave Hoodie
# 228           10229                          Google Nest Wifi Router
# 235           10236  Nespresso Vertuo Next Coffee and Espresso Maker
#
#      Total Revenue
# 5           149.95
# 10          129.99
# 15          107.97
# 20          179.97
# 25          179.99
# 32          149.95
# 40          105.00
# 45          130.00
# 56          149.95
# 64          102.00
# 80          179.98
# 82          100.00
# 83          149.94
# 88          105.00
# 91          179.99
# 98          119.94
# 104         119.97
# 109         159.99
# 116         149.97
# 131         159.80
# 133         159.98
# 134         139.96
# 139         139.99
# 140         134.97
# 152         164.97
# 164         149.95
# 167         149.97
# 170         104.97
# 174         149.97
# 179         146.00
# 182         179.97
# 188         139.96
# 191         169.95
# 196         125.00
# 200         179.97
# 209         129.00
# 218         149.97
# 228         169.00
# 235         159.99

# %% [markdown]
# Ejemplo 3: Units Sold entre 2 y 5 (excluyendo ambos límites)

# %%
df[df["Units Sold"].between(2, 5, inclusive="neither")][["Product Name", "Units Sold"]]
# Out:
#                                 Product Name  Units Sold
# 2                           Levi's 501 Jeans           3
# 3                          The Da Vinci Code           4
# 11          Babolat Pure Drive Tennis Racket           3
# 15     Salt, Fat, Acid, Heat by Samin Nosrat           3
# 17                      Manduka PRO Yoga Mat           4
# ..                                       ...         ...
# 225   The Silent Patient by Alex Michaelides           3
# 230          Adidas Originals Trefoil Hoodie           4
# 233  Hydro Flask Standard Mouth Water Bottle           3
# 236                Nike Air Force 1 Sneakers           3
# 237   The Handmaid's Tale by Margaret Atwood           3
#
# [67 rows x 2 columns]

# %% [markdown]
#  Ejemplo 4: Filtrar por fecha entre "2024-03-01" y "2024-06-30"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    240 non-null    int64
#  1   Date              240 non-null    object
#  2   Product Category  240 non-null    object
#  3   Product Name      240 non-null    object
#  4   Units Sold        240 non-null    int64
#  5   Unit Price        240 non-null    float64
#  6   Total Revenue     240 non-null    float64
#  7   Region            240 non-null    object
#  8   Payment Method    240 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 17.0+ KB

# %%
df["Date"] = pd.to_datetime(df["Date"])#para transformar a Fecha

df[df["Date"].between("2024-03-01", "2024-06-30" ,inclusive="both")][["Transaction ID", "Date", "Product Name"]]
# Out:
#      Transaction ID       Date                            Product Name
# 60            10061 2024-03-01                         Nintendo Switch
# 61            10062 2024-03-02                    Philips Airfryer XXL
# 62            10063 2024-03-03               Hanes ComfortSoft T-Shirt
# 63            10064 2024-03-04  Where the Crawdads Sing by Delia Owens
# 64            10065 2024-03-05                Lancome La Vie Est Belle
# ..              ...        ...                                     ...
# 177           10178 2024-06-26  The Sun Also Rises by Ernest Hemingway
# 178           10179 2024-06-27     First Aid Beauty Ultra Repair Cream
# 179           10180 2024-06-28              Oakley Holbrook Sunglasses
# 180           10181 2024-06-29                     Google Pixelbook Go
# 181           10182 2024-06-30                       Dyson V8 Absolute
#
# [122 rows x 3 columns]

# %% [markdown]
# ---
# ###  Filtrado con .str.contains( )
# ---

# %% [markdown]
# El método `.str.contains()` permite verificar si una cadena de texto contiene un patrón específico (palabra, fragmento, regex).
#
# Muy útil cuando buscamos por nombre de producto, descripción o categoría.
#
# ```Python
# #sintaxis
# df["columna"].str.contains(pat, case=True, na=False, regex=True)
#
# ```
#
#  Parámetros clave:
#
# | Parámetro | Significado                                                      |
# | --------- | ---------------------------------------------------------------- |
# | `pat`     | Texto o patrón a buscar. Puede ser string o regex.               |
# | `case`    | `True` → sensible a mayúsculas/minúsculas; `False` → insensible. |
# | `na`      | Cómo tratar los valores nulos (`True`, `False`, o `np.nan`).     |
# | `regex`   | Si se trata como expresión regular (por defecto `True`).         |

# %% [markdown]
# | Ejemplo                                                  | Significado                                        |
# | -------------------------------------------------------- | -------------------------------------------------- |
# | `df["col"].str.contains("Mug")`                          | Contiene exactamente "Mug" (sensible a mayúsculas) |
# | `df["col"].str.contains("mug", case=False)`              | Contiene "mug", sin importar mayúsculas            |
# | `df["col"].str.contains("^Gap", case=False, regex=True)` | Comienza con "Gap" (regex)                         |

# %% [markdown]
#  Ejemplo 1: Productos cuyo nombre contiene "Jeans"

# %%
df[df["Product Name"].str.contains("jeans", case=False, na=False)]
# Out:
#      Transaction ID       Date Product Category  \
# 2             10003 2024-01-03         Clothing
# 104           10105 2024-04-14         Clothing
# 116           10117 2024-04-26         Clothing
# 182           10183 2024-07-01         Clothing
# 200           10201 2024-07-19         Clothing
# 224           10225 2024-08-12         Clothing
#
#                                       Product Name  Units Sold  Unit Price  \
# 2                                 Levi's 501 Jeans           3       69.99
# 104                             H&M Slim Fit Jeans           3       39.99
# 116                     Gap High Rise Skinny Jeans           3       49.99
# 182                      Levi's 511 Slim Fit Jeans           3       59.99
# 200                    Gap 1969 Original Fit Jeans           3       59.99
# 224  Old Navy Mid-Rise Rockstar Super Skinny Jeans           2       44.99
#
#      Total Revenue Region Payment Method
# 2           209.97   Asia     Debit Card
# 104         119.97   Asia     Debit Card
# 116         149.97   Asia     Debit Card
# 182         179.97   Asia     Debit Card
# 200         179.97   Asia     Debit Card
# 224          89.98   Asia     Debit Card

# %% [markdown]
# Ejemplo 2: Productos que contienen la palabra "gap" (sin importar mayúsculas)

# %%
df[df["Product Name"].str.contains("gap", case=False, na=False)][["Product Name", "Product Category"]]
# Out:
#                        Product Name Product Category
# 98   Gap Essential Crewneck T-Shirt         Clothing
# 116      Gap High Rise Skinny Jeans         Clothing
# 134         Gap Crewneck Sweatshirt         Clothing
# 200     Gap 1969 Original Fit Jeans         Clothing

# %% [markdown]
# Ejemplo 3: Productos cuyo nombre empieza con “Hanes”

# %%
df[df["Product Name"].str.contains("^Hanes", case=False, na=False, regex=True)][["Product Name", "Region" ,"Unit Price"]]
# Out:
#                  Product Name Region  Unit Price
# 62  Hanes ComfortSoft T-Shirt   Asia        9.99

# %% [markdown]
# Ejemplo 4: Filtrar productos que contengan la palabra “water” (insensible a mayúsculas)

# %%
df[df["Product Name"].str.contains("water", case=False, na=False)][["Product Name", "Total Revenue"]]
# Out:
#                                     Product Name  Total Revenue
# 94                        Tatcha The Water Cream          68.00
# 112  Biore UV Aqua Rich Watery Essence Sunscreen          15.00
# 131          Hydro Flask Wide Mouth Water Bottle         159.80
# 148                  Laneige Water Sleeping Mask          25.00
# 166             Neutrogena Hydro Boost Water Gel          16.99
# 233      Hydro Flask Standard Mouth Water Bottle          98.85

# %% [markdown]
# ---
# ###  Filtrado con .filter( )
# ---

# %% [markdown]
# El método .filter() se utiliza para filtrar columnas o filas basándose en sus etiquetas (nombres). No filtra por contenido, sino por coincidencia del nombre de columnas o índices.
#
# ```python
# df.filter(items = None, like = None, regex = None,axis = None)
#
# '''
# Donde:
#
# - df: Nombre del DataFrame que vamos a utilizar.
# - items (opcional): Lista con las etiquetas que queremos filtrar.
# - like (opcional): Patrón de texto que debe tener la etiqueta a filtrar.
# - regex (opcional): La etiqueta debe tener la expresión regular especificada.
# - axis: 0 para ver las filas que cumplen la condición. 1 para ver las columnas.
# '''
# ```
# Parámetros clave:
#
# | Parámetro | Uso                                                                           |
# | --------- | ----------------------------------------------------------------------------- |
# | `items`   | Lista exacta de nombres de columnas o filas que se quieren mantener.          |
# | `like`    | Texto que debe estar incluido en el nombre (como `contains` pero en nombres). |
# | `regex`   | Expresión regular aplicada a los nombres de las columnas o filas.             |
# | `axis`    | `0` para filas (índices), `1` para columnas.                                  |

# %% [markdown]
# | Ejemplo                                       | Resultado                                       |
# | --------------------------------------------- | ----------------------------------------------- |
# | `df.filter(like="Price", axis=1)`             | Selecciona columnas que contengan “Price”       |
# | `df.filter(items=["Product Name", "Region"])` | Selecciona solo esas columnas exactas           |
# | `df.filter(regex="^P.*e$", axis=1)`           | Columnas que empiezan con “P” y terminan en “e” |

# %% [markdown]
# Ejemplo 1: Seleccionar todas las columnas que contienen la palabra "Product"

# %%
df.filter(like="Product", axis=1)
# Out:
#     Product Category                                     Product Name
# 0        Electronics                                    iPhone 14 Pro
# 1    Home Appliances                                 Dyson V11 Vacuum
# 2           Clothing                                 Levi's 501 Jeans
# 3              Books                                The Da Vinci Code
# 4    Beauty Products                          Neutrogena Skincare Set
# ..               ...                                              ...
# 235  Home Appliances  Nespresso Vertuo Next Coffee and Espresso Maker
# 236         Clothing                        Nike Air Force 1 Sneakers
# 237            Books           The Handmaid's Tale by Margaret Atwood
# 238  Beauty Products             Sunday Riley Luna Sleeping Night Oil
# 239           Sports                       Yeti Rambler 20 oz Tumbler
#
# [240 rows x 2 columns]

# %% [markdown]
# Ejemplo 2: Seleccionar las columnas "Product Name" y "Region" usando items

# %%
df.filter(items=["Product Name", "Region"], axis=1)
# Out:
#                                         Product Name         Region
# 0                                      iPhone 14 Pro  North America
# 1                                   Dyson V11 Vacuum         Europe
# 2                                   Levi's 501 Jeans           Asia
# 3                                  The Da Vinci Code  North America
# 4                            Neutrogena Skincare Set         Europe
# ..                                               ...            ...
# 235  Nespresso Vertuo Next Coffee and Espresso Maker         Europe
# 236                        Nike Air Force 1 Sneakers           Asia
# 237           The Handmaid's Tale by Margaret Atwood  North America
# 238             Sunday Riley Luna Sleeping Night Oil         Europe
# 239                       Yeti Rambler 20 oz Tumbler           Asia
#
# [240 rows x 2 columns]

# %% [markdown]
# Ejemplo 3: Seleccionar columnas que empiezan con la letra "P" y terminan en "e"

# %%
df.filter(regex="^P.*e$", axis=1)
# Out:
#                                         Product Name
# 0                                      iPhone 14 Pro
# 1                                   Dyson V11 Vacuum
# 2                                   Levi's 501 Jeans
# 3                                  The Da Vinci Code
# 4                            Neutrogena Skincare Set
# ..                                               ...
# 235  Nespresso Vertuo Next Coffee and Espresso Maker
# 236                        Nike Air Force 1 Sneakers
# 237           The Handmaid's Tale by Margaret Atwood
# 238             Sunday Riley Luna Sleeping Night Oil
# 239                       Yeti Rambler 20 oz Tumbler
#
# [240 rows x 1 columns]

# %% [markdown]
# Ejemplo 4: Seleccionar columnas que contengan la palabra "Revenue"

# %%
df.filter(like="Revenue", axis=1)
# Out:
#      Total Revenue
# 0          1999.98
# 1           499.99
# 2           209.97
# 3            63.96
# 4            89.99
# ..             ...
# 235         159.99
# 236         270.00
# 237          32.97
# 238          55.00
# 239          59.98
#
# [240 rows x 1 columns]

# %% [markdown]
# Ejemplo 5: Seleccionar filas que tengan un índice específico (si el DataFrame tuviera un índice por ID)
#
# Esto solo aplica si has hecho algo como df.set_index("Transaction ID")

# %%
df.set_index("Transaction ID").filter(items=[10020, 10201], axis=0)
# Out:
#             Date Product Category                 Product Name  Units Sold  \
# 10020 2024-01-20  Home Appliances   Ninja Professional Blender           1
# 10201 2024-07-19         Clothing  Gap 1969 Original Fit Jeans           3
#
#        Unit Price  Total Revenue  Region Payment Method
# 10020       99.99          99.99  Europe         PayPal
# 10201       59.99         179.97    Asia     Debit Card
